# %%
import pandas as pd
import matplotlib.pyplot as plt

# Function to load and prepare data
def load_data(filename):
    df = pd.read_csv(filename)
    # Convert the 'date' column to datetime format
    df['date'] = pd.to_datetime(df['date'], format='%Y%m%d')
    return df

# Load data for all stocks
aapl = load_data('2-year sample/aapl_merged.csv')
amd = load_data('2-year sample/amd_merged.csv')
amzn = load_data('2-year sample/amzn_merged.csv')
fb = load_data('2-year sample/fb_merged.csv')
msft = load_data('2-year sample/msft_merged.csv')
nflx = load_data('2-year sample/nflx_merged.csv')
nvda = load_data('2-year sample/nvda_merged.csv')
tsla = load_data('2-year sample/tsla_merged.csv')
visa = load_data('2-year sample/v_merged.csv')
xom = load_data('2-year sample/xom_merged.csv')

# Preview the first dataset (Apple Inc.)
aapl.head()
# Out:
#         date  minute     open     high      low    close    volume
# 0 2019-03-25     700  46.7357  46.7971  46.7357  46.7971  21878.10
# 1 2019-03-25     701  46.7775  46.7996  46.7652  46.7775  17726.30
# 2 2019-03-25     702  46.7971  46.7996  46.7529  46.7529  13277.40
# 3 2019-03-25     703  46.7406  46.7406  46.7332  46.7332   3256.27
# 4 2019-03-25     704  46.7406  46.7406  46.7332  46.7332   3524.91

# %%
# Get basic information about the dataset
aapl_info = aapl.info()
aapl_description = aapl.describe()

aapl_info, aapl_description
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16164 entries, 0 to 16163
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    16164 non-null  datetime64[ns]
#  1   minute  16164 non-null  int64
#  2   open    16164 non-null  float64
#  3   high    16164 non-null  float64
#  4   low     16164 non-null  float64
#  5   close   16164 non-null  float64
#  6   volume  16164 non-null  float64
# dtypes: datetime64[ns](1), float64(5), int64(1)
# memory usage: 884.1 KB
# (None,
#                                  date        minute          open  \
#  count                          16164  16164.000000  16164.000000
#  mean   2019-04-08 19:13:45.835189248   1298.389198     48.508495
#  min              2019-03-25 00:00:00    700.000000     45.426200
#  25%              2019-04-01 00:00:00   1012.750000     47.005900
#  50%              2019-04-09 00:00:00   1308.000000     48.846100
#  75%              2019-04-17 00:00:00   1604.000000     49.609325
#  max              2019-04-25 00:00:00   1959.000000     51.215700
#  std                              NaN    349.414567      1.490465
#
#                 high           low         close        volume
#  count  16164.000000  16164.000000  16164.000000  1.616400e+04
#  mean      48.522201     48.491493     48.508551  1.582613e+05
#  min       45.554000     36.343400     45.428700  4.070300e+00
#  25%       47.023100     46.986300     47.005900  2.055520e+03
#  50%       48.858400     48.838700     48.843600  7.353265e+04
#  75%       49.622400     49.590500     49.608975  1.790742e+05
#  max       51.219300     51.199700     51.214400  3.304670e+07
#  std        1.488480      1.500990      1.490596  7.194011e+05  )

# %%
amd_info = amd.info()
amd_description = amd.describe()

amd_info, amd_description
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16227 entries, 0 to 16226
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    16227 non-null  datetime64[ns]
#  1   minute  16227 non-null  int64
#  2   open    16227 non-null  float64
#  3   high    16227 non-null  float64
#  4   low     16227 non-null  float64
#  5   close   16227 non-null  float64
#  6   volume  16227 non-null  float64
# dtypes: datetime64[ns](1), float64(5), int64(1)
# memory usage: 887.5 KB
# (None,
#                                  date        minute          open  \
#  count                          16227  16227.000000  16227.000000
#  mean   2019-04-08 20:25:04.159733760   1303.629322     27.399765
#  min              2019-03-25 00:00:00    700.000000     24.570000
#  25%              2019-04-01 00:00:00   1015.000000     26.390000
#  50%              2019-04-09 00:00:00   1311.000000     27.705000
#  75%              2019-04-17 00:00:00   1607.000000     28.180000
#  max              2019-04-25 00:00:00   1959.000000     29.940000
#  std                              NaN    350.940265      1.211937
#
#                 high           low         close        volume
#  count  16227.000000  16227.000000  16227.000000  1.622700e+04
#  mean      27.414968     27.383243     27.399473  9.240208e+04
#  min       24.630000     20.210000     24.570000  1.000000e+00
#  25%       26.400000     26.370000     26.390000  1.774500e+03
#  50%       27.720000     27.690000     27.705000  3.599800e+04
#  75%       28.185800     28.170000     28.180000  1.114370e+05
#  max       29.950000     29.910000     29.940000  6.790500e+06
#  std        1.212050      1.212961      1.211885  1.912443e+05  )

# %%
import matplotlib.pyplot as plt

stocks = [aapl, amd, amzn, fb, msft, nflx, nvda, tsla, visa, xom]
stock_names = ["AAPL", "AMD", "AMZN", "FB", "MSFT", "NFLX", "NVDA", "TSLA", "VISA", "XOM"]

# Plotting function for price and volume
def plot_stocks(stocks, stock_names):
    plt.figure(figsize=(15, 30))
    for i, stock in enumerate(stocks):
        

        # Plot high
        ax2 = plt.subplot(len(stocks), 3, 2*i+2)
        ax2.plot(stock['date'], stock['high'], label='High Price', color='green')
        ax2.set_title(f'{stock_names[i]} High')
        ax2.set_ylabel('Price ($)')
        ax2.grid(True)
        ax2.xticks(rotation=45, ha='right')

        # Plot volume
        ax3 = plt.subplot(len(stocks), 3, 2*i+3)
        ax3.plot(stock['date'], stock['volume'], label='Volume', color='red')
        ax3.set_title(f'{stock_names[i]} Volume')
        ax3.set_ylabel('Volume')
        ax3.grid(True)
        ax3.xticks(rotation=45, ha='right')

    plt.tight_layout()
    plt.show()

plot_stocks(stocks, stock_names)

# %%
stocks
# Out:
# [            date  minute     open     high      low    close    volume
#  0     2019-03-25     700  46.7357  46.7971  46.7357  46.7971  21878.10
#  1     2019-03-25     701  46.7775  46.7996  46.7652  46.7775  17726.30
#  2     2019-03-25     702  46.7971  46.7996  46.7529  46.7529  13277.40
#  3     2019-03-25     703  46.7406  46.7406  46.7332  46.7332   3256.27
#  4     2019-03-25     704  46.7406  46.7406  46.7332  46.7332   3524.91
#  ...          ...     ...      ...      ...      ...      ...       ...
#  16159 2019-04-25    1955  50.3570  50.3644  50.3570  50.3644  18007.20
#  16160 2019-04-25    1956  50.3570  50.3570  50.3521  50.3570   4070.34
#  16161 2019-04-25    1957  50.3644  50.3644  50.3644  50.3644   4070.34
#  16162 2019-04-25    1958  50.3570  50.4062  50.3570  50.3644   2381.15
#  16163 2019-04-25    1959  50.3644  50.4062  50.3644  50.4062   3256.27
#
#  [16164 rows x 7 columns],
#              date  minute   open   high    low  close   volume
#  0     2019-03-25     700  26.10  26.14  26.06  26.14   3752.0
#  1     2019-03-25     701  26.11  26.11  26.03  26.03  11990.0
#  2     2019-03-25     702  26.05  26.05  26.03  26.05   1066.0
#  3     2019-03-25     703  26.07  26.07  26.05  26.05   2800.0
#  4     2019-03-25     704  26.05  26.06  26.03  26.03   1214.0
#  ...          ...     ...    ...    ...    ...    ...      ...
#  16222 2019-04-25    1955  27.27  27.27  27.27  27.27     50.0
#  16223 2019-04-25    1956  27.27  27.28  27.25  27.25   8979.0
#  16224 2019-04-25    1957  27.25  27.25  27.25  27.25   1034.0
#  16225 2019-04-25    1958  27.27  27.27  27.25  27.27  17150.0
#  16226 2019-04-25    1959  27.25  27.28  27.25  27.28  17830.0
#
#  [16227 rows x 7 columns],
#              date  minute     open     high      low    close  volume
#  0     2019-03-25     700  1756.56  1759.00  1754.39  1757.05  1012.0
#  1     2019-03-25     701  1757.05  1758.00  1756.21  1758.00   219.0
#  2     2019-03-25     702  1757.00  1757.80  1756.50  1756.51   125.0
#  3     2019-03-25     703  1757.40  1758.00  1754.41  1754.41   871.0
#  4     2019-03-25     704  1755.30  1755.79  1754.26  1755.00   129.0
#  ...          ...     ...      ...      ...      ...      ...     ...
#  16238 2019-04-25    1955  1913.77  1914.50  1913.77  1914.00   984.0
#  16239 2019-04-25    1956  1914.00  1914.00  1912.50  1912.80  1050.0
#  16240 2019-04-25    1957  1912.80  1912.99  1911.99  1912.09  2139.0
#  16241 2019-04-25    1958  1911.55  1912.97  1911.00  1912.50   516.0
#  16242 2019-04-25    1959  1912.28  1914.00  1912.00  1913.89  1666.0
#
#  [16243 rows x 7 columns],
#              date  minute    open    high     low   close  volume
#  0     2019-03-25     700  163.75  163.75  163.50  163.75   751.0
#  1     2019-03-25     701  163.74  163.74  163.74  163.74   100.0
#  2     2019-03-25     702  163.74  163.75  163.74  163.75   600.0
#  3     2019-03-25     703  163.60  163.75  163.60  163.75  1060.0
#  4     2019-03-25     705  163.60  163.60  163.50  163.50   134.0
#  ...          ...     ...     ...     ...     ...     ...     ...
#  14932 2019-04-25    1955  192.55  192.56  192.55  192.55  1120.0
#  14933 2019-04-25    1956  192.55  192.55  192.55  192.55   100.0
#  14934 2019-04-25    1957  192.55  192.55  192.55  192.55   152.0
#  14935 2019-04-25    1958  192.55  192.60  192.55  192.57   838.0
#  14936 2019-04-25    1959  192.57  192.65  192.50  192.50   610.0
#
#  [14937 rows x 7 columns],
#              date  minute     open     high      low    close     volume
#  0     2019-03-25     700  114.378  114.437  114.280  114.437   678.0620
#  1     2019-03-25     701  114.378  114.378  114.378  114.378   102.1180
#  2     2019-03-25     703  114.378  114.378  114.378  114.378   102.1180
#  3     2019-03-25     704  114.319  114.319  114.280  114.319  3970.3400
#  4     2019-03-25     706  114.378  114.378  114.378  114.378    15.3177
#  ...          ...     ...      ...      ...      ...      ...        ...
#  14247 2019-04-25    1952  126.335  126.403  126.325  126.403   209.3410
#  14248 2019-04-25    1953  126.403  126.403  126.325  126.325    62.2918
#  14249 2019-04-25    1954  126.374  126.374  126.374  126.374    15.3177
#  14250 2019-04-25    1958  126.325  126.325  126.325  126.325   405.4080
#  14251 2019-04-25    1959  126.325  126.383  126.325  126.383   204.2360
#
#  [14252 rows x 7 columns],
#              date  minute    open    high     low   close  volume
#  0     2019-03-25     700  359.11  360.58  359.09  359.95   576.0
#  1     2019-03-25     702  359.22  359.41  359.22  359.41    34.0
#  2     2019-03-25     703  359.11  359.87  359.11  359.87    91.0
#  3     2019-03-25     708  359.29  359.29  359.22  359.22   100.0
#  4     2019-03-25     709  359.45  359.47  359.45  359.47   131.0
#  ...          ...     ...     ...     ...     ...     ...     ...
#  14924 2019-04-25    1950  367.00  367.05  367.00  367.00   113.0
#  14925 2019-04-25    1951  366.80  366.80  366.80  366.80    25.0
#  14926 2019-04-25    1953  367.00  367.00  367.00  367.00    21.0
#  14927 2019-04-25    1958  367.00  367.00  367.00  367.00    50.0
#  14928 2019-04-25    1959  366.77  367.07  366.76  367.07   270.0
#
#  [14929 rows x 7 columns],
#              date  minute     open     high      low    close     volume
#  0     2019-03-25     700  175.764  175.764  175.207  175.257   304.3720
#  1     2019-03-25     703  175.595  175.705  175.595  175.705   557.5130
#  2     2019-03-25     704  175.456  175.456  175.257  175.257   263.1860
#  3     2019-03-25     705  175.456  175.456  175.456  175.456    16.0724
#  4     2019-03-25     706  175.406  175.406  175.406  175.406    10.0453
#  ...          ...     ...      ...      ...      ...      ...        ...
#  14948 2019-04-25    1955  181.429  181.429  181.429  181.429   401.8110
#  14949 2019-04-25    1956  181.429  181.578  181.429  181.578   141.6380
#  14950 2019-04-25    1957  181.429  181.578  181.429  181.578  1077.8600
#  14951 2019-04-25    1958  181.528  181.678  181.528  181.678  1732.8100
#  14952 2019-04-25    1959  181.628  181.628  181.379  181.503   210.9510
#
#  [14953 rows x 7 columns],
#              date  minute    open    high     low   close   volume
#  0     2019-03-25     700  52.256  52.330  52.200  52.252  13040.0
#  1     2019-03-25     701  52.258  52.298  52.226  52.298   4000.0
#  2     2019-03-25     702  52.298  52.300  52.268  52.268   6250.0
#  3     2019-03-25     703  52.294  52.338  52.274  52.300   2550.0
#  4     2019-03-25     704  52.338  52.338  52.300  52.300   5055.0
#  ...          ...     ...     ...     ...     ...     ...      ...
#  16097 2019-04-25    1955  49.380  49.406  49.370  49.406   2000.0
#  16098 2019-04-25    1956  49.406  49.458  49.406  49.456   1155.0
#  16099 2019-04-25    1957  49.458  49.458  49.456  49.456   1000.0
#  16100 2019-04-25    1958  49.420  49.458  49.404  49.458   1170.0
#  16101 2019-04-25    1959  49.458  49.458  49.440  49.440    170.0
#
#  [16102 rows x 7 columns],
#              date  minute     open     high      low    close      volume
#  0     2019-03-25     700  151.348  151.358  151.348  151.358    691.4190
#  1     2019-03-25     703  151.358  151.358  151.358  151.358     85.9220
#  2     2019-03-25     709  151.249  151.249  151.249  151.249     92.9979
#  3     2019-03-25     712  151.249  151.249  151.249  151.249     13.1410
#  4     2019-03-25     713  151.249  151.249  151.249  151.249     17.1844
#  ...          ...     ...      ...      ...      ...      ...         ...
#  11342 2019-04-25    1829  159.292  159.292  159.292  159.292  15764.2000
#  11343 2019-04-25    1839  159.124  159.124  159.124  159.124    187.0070
#  11344 2019-04-25    1910  159.025  159.272  159.025  159.272    606.5080
#  11345 2019-04-25    1919  159.262  159.262  159.262  159.262     35.3796
#  11346 2019-04-25    1935  159.262  159.262  159.262  159.262     60.6508
#
#  [11347 rows x 7 columns],
#              date  minute     open     high      low    close    volume
#  0     2019-03-25     700  72.2595  72.2595  71.7502  71.9736  848.3230
#  1     2019-03-25     701  71.9557  71.9557  71.9557  71.9557  396.1830
#  2     2019-03-25     712  71.9111  71.9111  71.9111  71.9111   39.1706
#  3     2019-03-25     716  71.9111  71.9111  71.9111  71.9111   52.6005
#  4     2019-03-25     727  71.8932  71.8932  71.8932  71.8932   44.7664
#  ...          ...     ...      ...      ...      ...      ...       ...
#  10531 2019-04-25    1946  73.6713  73.6713  73.6713  73.6713   55.9580
#  10532 2019-04-25    1950  73.6713  73.6713  73.6713  73.6713  102.9630
#  10533 2019-04-25    1953  73.5373  73.5373  73.5373  73.5373    4.4766
#  10534 2019-04-25    1958  73.6713  73.6713  73.6713  73.6713   42.5281
#  10535 2019-04-25    1959  73.7160  73.7160  73.7160  73.7160  336.8670
#
#  [10536 rows x 7 columns]]

# %% [markdown]
# #### Merging the datasets for better cross-section analysis

# %%
# Merging function
def merge_data(tickers):
    # Load the data for each ticker
    data_frames = {ticker: load_data("2-year sample/"f'{ticker}_merged.csv') for ticker in tickers}

    # Rename the columns in each DataFrame except 'date' and 'minute'
    for ticker, df in data_frames.items():
        df.rename(columns=lambda name: f"{ticker}_{name}" if name not in ['date', 'minute'] else name, inplace=True)

    # Initialize merged DataFrame as the first ticker's DataFrame
    merged_df = list(data_frames.values())[0]

    # Merge each DataFrame on 'date' and 'minute'
    for ticker, df in data_frames.items():
        if ticker == list(data_frames.keys())[0]:  # Skip the first ticker as it is already in merged_df
            continue
        merged_df = pd.merge(merged_df, df, on=['date', 'minute'], how='outer')

    return merged_df

# List of tickers
tickers = ['aapl', 'amd', 'amzn', 'fb', 'msft', 'nflx', 'nvda', 'tsla', 'v', 'xom']

# Call the merge function
combined_df = merge_data(tickers)
combined_df.dropna(inplace=True)

# %%
combined_df.head(20)
# Out:
#                           date  minute  aapl_open  aapl_high  aapl_low  \
# datetime
# 2019-03-25 07:00:00 2019-03-25     700    46.7357    46.7971   46.7357
# 2019-03-25 08:00:00 2019-03-25     800    46.7775    46.8020   46.7160
# 2019-03-25 08:35:00 2019-03-25     835    47.2934    47.3769   46.9372
# 2019-03-25 08:59:00 2019-03-25     859    47.2909    47.2909   47.2565
# 2019-03-25 09:01:00 2019-03-25     901    47.2885    47.3106   46.9372
# 2019-03-25 09:02:00 2019-03-25     902    47.2492    47.2885   46.9372
# 2019-03-25 09:03:00 2019-03-25     903    47.2688    47.2811   47.2344
# 2019-03-25 09:07:00 2019-03-25     907    47.1533    47.1705   47.1337
# 2019-03-25 09:08:00 2019-03-25     908    47.1362    47.1362   47.0993
# 2019-03-25 09:09:00 2019-03-25     909    47.1165    47.1705   47.1042
# 2019-03-25 09:10:00 2019-03-25     910    47.1362    47.1681   47.1263
# 2019-03-25 09:19:00 2019-03-25     919    47.1337    47.1337   47.0870
# 2019-03-25 09:26:00 2019-03-25     926    47.0944    47.0968   47.0747
# 2019-03-25 09:27:00 2019-03-25     927    47.0846    47.1312   47.0772
# 2019-03-25 09:28:00 2019-03-25     928    47.0772    47.0870   47.0281
# 2019-03-25 09:29:00 2019-03-25     929    47.0728    47.0772   47.0354
# 2019-03-25 09:30:00 2019-03-25     930    47.0993    47.1042   46.9617
# 2019-03-25 09:31:00 2019-03-25     931    47.0452    47.1656   47.0035
# 2019-03-25 09:32:00 2019-03-25     932    47.0207    47.0691   46.9347
# 2019-03-25 09:33:00 2019-03-25     933    47.0067    47.0207   46.8364
#
#                      aapl_close  aapl_volume  amd_open  amd_high  amd_low  \
# datetime
# 2019-03-25 07:00:00     46.7971     21878.10   26.1000     26.14  26.0600
# 2019-03-25 08:00:00     46.7504    143463.00   25.9200     26.14  25.8200
# 2019-03-25 08:35:00     47.3376     48327.10   26.1300     26.13  26.1100
# 2019-03-25 08:59:00     47.2909      2336.37   26.4000     26.42  26.3500
# 2019-03-25 09:01:00     47.2590     18800.90   26.3700     26.40  26.3600
# 2019-03-25 09:02:00     47.2688      3927.87   26.3700     26.37  26.3000
# 2019-03-25 09:03:00     47.2344     13525.70   26.3000     26.31  26.2700
# 2019-03-25 09:07:00     47.1337     54550.70   26.3400     26.35  26.3000
# 2019-03-25 09:08:00     47.1091     38533.90   26.3300     26.34  26.3000
# 2019-03-25 09:09:00     47.1460     34976.40   26.3400     26.34  26.2900
# 2019-03-25 09:10:00     47.1312     18951.50   26.3000     26.34  26.2900
# 2019-03-25 09:19:00     47.1165     30263.00   26.3300     26.34  26.2400
# 2019-03-25 09:26:00     47.0895     49450.50   26.1500     26.30  26.1200
# 2019-03-25 09:27:00     47.1091     19960.90   26.2600     26.29  26.1600
# 2019-03-25 09:28:00     47.0772     58840.80   26.2600     26.39  26.2000
# 2019-03-25 09:29:00     47.0772      9146.05   26.3300     26.40  26.2700
# 2019-03-25 09:30:00     47.0526   4360850.00   26.2900     26.37  26.1600
# 2019-03-25 09:31:00     47.0163   1092860.00   26.2685     26.58  26.2685
# 2019-03-25 09:32:00     47.0084    931008.00   26.5700     26.77  26.5500
# 2019-03-25 09:33:00     46.8610   1254290.00   26.7637     26.78  26.5800
#
#                      ...    v_low  v_close     v_volume  xom_open  xom_high  \
# datetime             ...
# 2019-03-25 07:00:00  ...  151.348  151.358     691.4190   72.2595   72.2595
# 2019-03-25 08:00:00  ...  150.659  151.052    2009.5600   71.7503   71.9557
# 2019-03-25 08:35:00  ...  151.428  151.428       2.0217   71.9111   71.9200
# 2019-03-25 08:59:00  ...  151.160  151.259      18.1952   71.7949   71.7949
# 2019-03-25 09:01:00  ...  151.309  151.428       3.0325   71.9111   71.9111
# 2019-03-25 09:02:00  ...  151.111  151.150     365.9270   71.9111   71.9111
# 2019-03-25 09:03:00  ...  151.141  151.141       1.0108   71.7681   71.7681
# 2019-03-25 09:07:00  ...  150.913  151.141       6.0651   71.7502   71.7502
# 2019-03-25 09:08:00  ...  151.131  151.141       5.0542   71.6966   71.6966
# 2019-03-25 09:09:00  ...  150.913  150.913       5.0542   71.6430   71.6430
# 2019-03-25 09:10:00  ...  150.626  150.643      48.5206   71.5545   71.5545
# 2019-03-25 09:19:00  ...  150.765  150.765       1.0108   71.5983   71.5983
# 2019-03-25 09:26:00  ...  150.488  151.081     325.4930   71.6073   71.6073
# 2019-03-25 09:27:00  ...  150.478  150.488     123.3230   71.4911   71.4911
# 2019-03-25 09:28:00  ...  150.478  150.567     974.4560   71.4822   71.4911
# 2019-03-25 09:29:00  ...  150.052  150.250     989.6190   71.4911   71.5537
# 2019-03-25 09:30:00  ...  149.914  150.112  249269.0000   71.5090   71.5894
# 2019-03-25 09:31:00  ...  150.122  150.349   31892.2000   71.4822   71.5715
# 2019-03-25 09:32:00  ...  150.310  150.912   31250.3000   71.4286   71.4286
# 2019-03-25 09:33:00  ...  150.775  150.963   21526.0000   71.3124   71.3750
#
#                      xom_low  xom_close   xom_volume  minute_str   date_only
# datetime
# 2019-03-25 07:00:00  71.7502    71.9736     848.3230        0700  2019-03-25
# 2019-03-25 08:00:00  71.7502    71.9557     746.4800        0800  2019-03-25
# 2019-03-25 08:35:00  71.7502    71.7502     374.9190        0835  2019-03-25
# 2019-03-25 08:59:00  71.7948    71.7948       2.2383        0859  2019-03-25
# 2019-03-25 09:01:00  71.9111    71.9111       4.4766        0901  2019-03-25
# 2019-03-25 09:02:00  71.9111    71.9111       4.4766        0902  2019-03-25
# 2019-03-25 09:03:00  71.7681    71.7681       1.1192        0903  2019-03-25
# 2019-03-25 09:07:00  71.6698    71.6698     223.8320        0907  2019-03-25
# 2019-03-25 09:08:00  71.6966    71.6966      23.5024        0908  2019-03-25
# 2019-03-25 09:09:00  71.6430    71.6430       1.1192        0909  2019-03-25
# 2019-03-25 09:10:00  71.5545    71.5545       3.3575        0910  2019-03-25
# 2019-03-25 09:19:00  71.5983    71.5983       4.4766        0919  2019-03-25
# 2019-03-25 09:26:00  71.4822    71.4822     223.8320        0926  2019-03-25
# 2019-03-25 09:27:00  71.4822    71.4822     294.3390        0927  2019-03-25
# 2019-03-25 09:28:00  71.4822    71.4822     200.3300        0928  2019-03-25
# 2019-03-25 09:29:00  71.4911    71.4911     423.0430        0929  2019-03-25
# 2019-03-25 09:30:00  71.3928    71.5000   20755.9000        0930  2019-03-25
# 2019-03-25 09:31:00  71.4107    71.4464  276623.0000        0931  2019-03-25
# 2019-03-25 09:32:00  71.3187    71.3213   70268.7000        0932  2019-03-25
# 2019-03-25 09:33:00  71.2767    71.3750  106870.0000        0933  2019-03-25
#
# [20 rows x 54 columns]

# %% [markdown]
# #### PCA Analysis on Volume

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
import pandas as pd

# Extract volume columns
volume_columns = [col for col in combined_df.columns if 'volume' in col]
volumes = combined_df[volume_columns]

# Standardize the volume data
scaler = StandardScaler()
volumes_standardized = scaler.fit_transform(volumes)

# Perform PCA
pca = PCA()
principal_components = pca.fit_transform(volumes_standardized)

# Calculate explained variance and cumulative explained variance
explained_variance = pca.explained_variance_ratio_
cumulative_explained_variance = explained_variance.cumsum()

# Find the number of components for optimal variance explained (>95% cumulative variance)
optimal_num_components = len(cumulative_explained_variance[cumulative_explained_variance < 0.95]) + 1

# Plotting the explained variance
plt.figure(figsize=(10, 5))
plt.bar(range(1, len(explained_variance) + 1), explained_variance, alpha=0.5, align='center', label='Individual explained variance')
plt.step(range(1, len(cumulative_explained_variance) + 1), cumulative_explained_variance, where='mid', label='Cumulative explained variance')
plt.axvline(optimal_num_components, color='k', linestyle='--', label='Optimal number of components')
plt.ylabel('Explained variance ratio')
plt.xlabel('Principal component index')
plt.legend(loc='best')
plt.title('Explained Variance by PCA Component')
plt.show()

# Output the principal components and the optimal number of components
print("Principal Components:\n", principal_components)
print("Optimal number of components:", optimal_num_components)
# Out:
# Principal Components:
#  [[-1.13248850e+00  4.28358442e-01 -3.43202745e-01 ... -1.12059788e-02
#   -6.00353281e-02 -3.17969192e-02]
#  [-7.24505717e-01  1.91363112e-01 -2.28569528e-01 ... -5.78624613e-02
#   -6.04361176e-02 -8.06623774e-03]
#  [-1.14503336e+00  4.48388526e-01 -3.75344117e-01 ...  8.30339259e-03
#   -9.01915590e-02 -2.83183223e-02]
#  ...
#  [-1.05744746e+00  4.31226505e-01 -3.89892575e-01 ... -9.79231786e-02
#    6.86648421e-02 -3.84940337e-04]
#  [-1.10317184e+00  4.21488718e-01 -3.63684360e-01 ...  1.79224305e-03
#   -1.44641317e-02 -2.56431613e-02]
#  [-9.34232717e-01  3.89436063e-01 -3.91625787e-01 ... -1.84658112e-01
#    1.70163114e-01  3.59023578e-02]]
# Optimal number of components: 7

# %%
# First PC
first_principal_component = -principal_components[0]

# Create bar chart
plt.figure(figsize=(12, 6))
plt.bar(tickers, first_principal_component, color='skyblue')
plt.xlabel('Ticker Name')
plt.ylabel('First Principal Component Value')
plt.title('First Principal Component for Each Ticker')
plt.show()

# %%
# Second PC
second_principal_component = -principal_components[1]

# Create bar chart
plt.figure(figsize=(12, 6))
plt.bar(tickers, second_principal_component, color='skyblue')
plt.xlabel('Ticker Name')
plt.ylabel('Second Principal Component Value')
plt.title('Second Principal Component for Each Ticker')
plt.show()

# %%
# Third PC
third_principal_component = -principal_components[2]

# Create bar chart
plt.figure(figsize=(12, 6))
plt.bar(tickers, third_principal_component, color='skyblue')
plt.xlabel('Ticker Name')
plt.ylabel('Third Principal Component Value')
plt.title('Third Principal Component for Each Ticker')
plt.show()

# %% [markdown]
# #### Construct minutely return series

# %%
def calculate_adjacent_returns(df, ticker):
    # Calculate the simple returns
    df[f'{ticker}_return'] = df[f'{ticker}_close'].pct_change()

    # Find out if the current minute is adjacent to the previous one
    def is_adjacent(curr, prev):
        # If it's the start of an hour, check if previous is end of previous hour
        if curr % 100 == 0 and prev % 100 == 59 and (curr // 100 - prev // 100) == 1:
            return True
        # Else, check if it's just the next minute
        return curr - prev == 1

    # Determine if the current row is adjacent to the previous row
    df['is_adjacent'] = [is_adjacent(curr, prev) for curr, prev in zip(df['minute'], df['minute'].shift(fill_value=df['minute'].iloc[0] - 1))]

    # Set returns to NaN where minutes are not adjacent
    df.loc[~df['is_adjacent'], f'{ticker}_return'] = None

    # Drop the 'is_adjacent' column as it is no longer needed
    df.drop(columns='is_adjacent', inplace=True)
    return df[f'{ticker}_return']

# Reinitialize returns_df to just contain 'date' and 'minute'
returns_df = combined_df[['date', 'minute']].copy()

# Calculate returns for each ticker and add to the returns DataFrame
for ticker in tickers:
    returns_series = calculate_adjacent_returns(combined_df.copy(), ticker)
    returns_df[f'{ticker}_return'] = returns_series

# Drop rows where all returns are NaN across all tickers
returns_df.dropna(how='all', subset=[f'{ticker}_return' for ticker in tickers], inplace=True)

# Reset index to clean up the DataFrame
returns_df.reset_index(drop=True, inplace=True)

# %%
returns_df.tail(10)
# Out:
#            date  minute  aapl_return  amd_return  amzn_return  fb_return  \
# 9190 2019-04-25    1628    -0.000083    0.003951    -0.000021   0.000000
# 9191 2019-04-25    1636     0.000853    0.001771     0.001137   0.000000
# 9192 2019-04-25    1641     0.000341   -0.001430     0.001813   0.001192
# 9193 2019-04-25    1642    -0.000341    0.000004    -0.000770  -0.001087
# 9194 2019-04-25    1650     0.000488   -0.001805    -0.000515   0.000415
# 9195 2019-04-25    1651    -0.000488   -0.002893     0.000000  -0.001193
# 9196 2019-04-25    1652     0.000878    0.000363     0.000629   0.001766
# 9197 2019-04-25    1653    -0.000877   -0.001813     0.000411  -0.001037
# 9198 2019-04-25    1701     0.000780    0.000000    -0.000104  -0.000311
# 9199 2019-04-25    1737     0.000000   -0.003292    -0.001444   0.000987
#
#       msft_return  nflx_return  nvda_return  tsla_return  v_return  xom_return
# 9190     0.000000     0.000000    -0.001041    -0.000323 -0.000992    0.001821
# 9191     0.000388    -0.000136     0.002087     0.000425  0.000000    0.000243
# 9192    -0.000150    -0.001249    -0.000442     0.000485 -0.000496   -0.003636
# 9193    -0.000316    -0.000136     0.000110    -0.000404  0.000496    0.003649
# 9194    -0.000546    -0.000027    -0.000105     0.000365  0.000000    0.000000
# 9195     0.001164    -0.001548    -0.001050     0.000405  0.000993    0.000000
# 9196    -0.000617     0.001550     0.001100     0.000000  0.000000    0.000000
# 9197     0.000926    -0.001222    -0.000381     0.000000  0.000000   -0.000849
# 9198     0.000000     0.000408     0.001981    -0.000283  0.000000    0.003162
# 9199     0.000389     0.000000     0.000000     0.000041  0.000931    0.000607

# %%
returns_df.describe()
# Out:
#                                 date       minute  aapl_return   amd_return  \
# count                           9200  9200.000000  9200.000000  9200.000000
# mean   2019-04-09 00:22:32.347826176  1253.757391     0.000005    -0.000016
# min              2019-03-25 00:00:00   831.000000    -0.005455    -0.014351
# 25%              2019-04-01 00:00:00  1104.000000    -0.000225    -0.000535
# 50%              2019-04-09 00:00:00  1244.000000     0.000015     0.000000
# 75%              2019-04-17 00:00:00  1424.000000     0.000244     0.000535
# max              2019-04-25 00:00:00  1748.000000     0.012533     0.011938
# std                              NaN   193.664065     0.000557     0.001162
#
#        amzn_return    fb_return  msft_return  nflx_return  nvda_return  \
# count  9200.000000  9200.000000  9200.000000  9200.000000  9200.000000
# mean      0.000001     0.000008     0.000002     0.000005    -0.000001
# min      -0.029198    -0.014037    -0.009609    -0.012679    -0.006559
# 25%      -0.000222    -0.000278    -0.000206    -0.000397    -0.000404
# 50%       0.000005     0.000000     0.000000     0.000008     0.000000
# 75%       0.000230     0.000282     0.000209     0.000416     0.000409
# max       0.016557     0.048994     0.013157     0.014404     0.017922
# std       0.000580     0.000823     0.000468     0.000897     0.000885
#
#        tsla_return     v_return   xom_return
# count  9200.000000  9200.000000  9200.000000
# mean      0.000008     0.000001     0.000001
# min      -0.013319    -0.006524    -0.010609
# 25%      -0.000459    -0.000191    -0.000225
# 50%       0.000000     0.000000     0.000000
# 75%       0.000460     0.000193     0.000224
# max       0.011736     0.009268     0.010723
# std       0.000989     0.000480     0.000503

# %% [markdown]
# ##### PCA on return

# %%
# Perform PCA on the returns, handling NaN values by imputing or ignoring them

# First, standardize the returns
returns_only_df = returns_df[[f'{ticker}_return' for ticker in tickers]]

# Impute NaN values with the mean return for each column before performing PCA
# This is a common method for handling NaNs in PCA, but other methods could be more appropriate depending on the context
returns_imputed = returns_only_df.fillna(returns_only_df.mean())

# Now standardize the imputed returns data
scaler = StandardScaler()
returns_standardized = scaler.fit_transform(returns_imputed)

# Perform PCA
pca = PCA()
principal_components = pca.fit_transform(returns_standardized)

# Calculate explained variance and cumulative explained variance
explained_variance = pca.explained_variance_ratio_
cumulative_explained_variance = explained_variance.cumsum()

# Find the number of components for optimal variance explained (>95% cumulative variance)
optimal_num_components = len(cumulative_explained_variance[cumulative_explained_variance < 0.95]) + 1

# Plotting the explained variance
plt.figure(figsize=(10, 5))
plt.bar(range(1, len(explained_variance) + 1), explained_variance, alpha=0.5, align='center', label='Individual explained variance')
plt.step(range(1, len(cumulative_explained_variance) + 1), cumulative_explained_variance, where='mid', label='Cumulative explained variance')
plt.axvline(optimal_num_components, color='k', linestyle='--', label='Optimal number of components')
plt.ylabel('Explained variance ratio')
plt.xlabel('Principal component index')
plt.legend(loc='best')
plt.title('Explained Variance by PCA Component')
plt.show()

# Output the principal components and the optimal number of components
print("Principal Components:\n", principal_components)
print("Explained variance by component:", explained_variance)
print("Optimal number of components:", optimal_num_components)
# Out:
# Principal Components:
#  [[ 2.45545286  0.4684129   0.07384317 ... -0.9810881  -2.68753788
#    1.43028235]
#  [ 2.55183357  1.74516038 -3.21086418 ...  0.77923932  0.55422183
#    0.35745051]
#  [ 0.60803967 -0.59052408  0.45765918 ...  1.03446888 -0.27603609
#   -0.92961267]
#  ...
#  [ 1.23947038  1.27203673 -0.3847695  ... -2.45072653 -1.13275551
#    0.25979674]
#  [-2.08712237 -2.79204884  4.72735167 ...  0.68982399 -0.31275688
#    1.98400605]
#  [ 0.49676147  1.62415532  2.41684126 ...  1.80495454 -0.21083644
#    2.2786336 ]]
# Explained variance by component: [0.33112722 0.10492644 0.0991365  0.09030044 0.08207062 0.07746505
#  0.06949119 0.05858688 0.04830461 0.03859106]
# Optimal number of components: 9

# %%
# First PC
first_principal_component = -principal_components[0]

# Create bar chart
plt.figure(figsize=(12, 6))
plt.bar(tickers, first_principal_component, color='skyblue')
plt.xlabel('Ticker Name')
plt.ylabel('First Principal Component Value')
plt.title('First Principal Component for Each Ticker')
plt.show()

# %%
# Second PC
second_principal_component = principal_components[1]

# Create bar chart
plt.figure(figsize=(12, 6))
plt.bar(tickers, second_principal_component, color='skyblue')
plt.xlabel('Ticker Name')
plt.ylabel('Second Principal Component Value')
plt.title('Second Principal Component for Each Ticker')
plt.show()

# %%
# Third PC
third_principal_component = principal_components[2]

# Create bar chart
plt.figure(figsize=(12, 6))
plt.bar(tickers, third_principal_component, color='skyblue')
plt.xlabel('Ticker Name')
plt.ylabel('Third Principal Component Value')
plt.title('Third Principal Component for Each Ticker')
plt.show()

# %%
pip install seaborn
# Out:
# Requirement already satisfied: seaborn in c:\users\dan\appdata\local\programs\python\python312\lib\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\dan\appdata\local\programs\python\python312\lib\site-packages (from seaborn) (1.26.4)
# Requirement already satisfied: pandas>=1.2 in c:\users\dan\appdata\local\programs\python\python312\lib\site-packages (from seaborn) (2.2.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\dan\appdata\local\programs\python\python312\lib\site-packages (from seaborn) (3.8.4)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\dan\appdata\local\programs\python\python312\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\dan\appdata\local\programs\python\python312\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\dan\appdata\local\programs\python\python312\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\dan\appdata\local\programs\python\python312\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\dan\appdata\local\programs\python\python312\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.0)
# Requirement already satisfied: pillow>=8 in c:\users\dan\appdata\local\programs\python\python312\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\dan\appdata\local\programs\python\python312\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\dan\appdata\local\programs\python\python312\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\dan\appdata\local\programs\python\python312\lib\site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\dan\appdata\local\programs\python\python312\lib\site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: six>=1.5 in c:\users\dan\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import seaborn as sns
import numpy as np

correlation_matrix = returns_imputed.corr()
mask = np.triu(np.ones_like(correlation_matrix, dtype=bool))

# Plotting the triangular heatmap
plt.figure(figsize=(12, 10))
triangular_heatmap = sns.heatmap(correlation_matrix, mask=mask, annot=True, fmt=".2f", cmap='coolwarm', cbar=True, square=True)
triangular_heatmap.set_title('Correlation Matrix of Minutely Returns', pad=20)
plt.show()

# %% [markdown]
# #### Return distributions

# %%
# Plotting the aggregate distribution of return series for each ticker using histograms

plt.figure(figsize=(15, 12))
for i, ticker in enumerate(tickers, 1):
    plt.subplot(5, 2, i)
    sns.histplot(returns_imputed[f'{ticker}_return'].dropna(), kde=True, color='skyblue', binwidth=0.001)
    plt.title(f'{ticker.upper()} Return Distribution')
    plt.xlabel('Returns')
    plt.ylabel('Frequency')

plt.tight_layout(pad=3.0)
plt.suptitle('Aggregate Distribution of Return Series for Each Ticker', size=16, y=1.02)
plt.show()

# %%
combined_df.head()
# Out:
#           date  minute  aapl_open  aapl_high  aapl_low  aapl_close  \
# 0   2019-03-25     700    46.7357    46.7971   46.7357     46.7971
# 60  2019-03-25     800    46.7775    46.8020   46.7160     46.7504
# 95  2019-03-25     835    47.2934    47.3769   46.9372     47.3376
# 119 2019-03-25     859    47.2909    47.2909   47.2565     47.2909
# 121 2019-03-25     901    47.2885    47.3106   46.9372     47.2590
#
#      aapl_volume  amd_open  amd_high  amd_low  ...   v_open   v_high    v_low  \
# 0       21878.10     26.10     26.14    26.06  ...  151.348  151.358  151.348
# 60     143463.00     25.92     26.14    25.82  ...  150.659  151.052  150.659
# 95      48327.10     26.13     26.13    26.11  ...  151.428  151.428  151.428
# 119      2336.37     26.40     26.42    26.35  ...  151.210  151.259  151.160
# 121     18800.90     26.37     26.40    26.36  ...  151.309  151.428  151.309
#
#      v_close   v_volume  xom_open  xom_high  xom_low  xom_close  xom_volume
# 0    151.358   691.4190   72.2595   72.2595  71.7502    71.9736    848.3230
# 60   151.052  2009.5600   71.7503   71.9557  71.7502    71.9557    746.4800
# 95   151.428     2.0217   71.9111   71.9200  71.7502    71.7502    374.9190
# 119  151.259    18.1952   71.7949   71.7949  71.7948    71.7948      2.2383
# 121  151.428     3.0325   71.9111   71.9111  71.9111    71.9111      4.4766
#
# [5 rows x 52 columns]

# %%
# Filter columns for each stock
aapl_columns = [col for col in combined_df.columns if 'aapl' in col.lower()]
amd_columns = [col for col in combined_df.columns if 'amd' in col.lower()]
amzn_columns = [col for col in combined_df.columns if 'amzn' in col.lower()]
fb_columns = [col for col in combined_df.columns if 'fb' in col.lower()]
msft_columns = [col for col in combined_df.columns if 'msft' in col.lower()]
nflx_columns = [col for col in combined_df.columns if 'nflx' in col.lower()]
nvda_columns = [col for col in combined_df.columns if 'nvda' in col.lower()]
tsla_columns = [col for col in combined_df.columns if 'tsla' in col.lower()]
v_columns = [col for col in combined_df.columns if 'v' in col.lower()]
xom_columns = [col for col in combined_df.columns if 'xom' in col.lower()]

# Create separate DataFrames for each stock
aapl_df = combined_df[['date', 'minute'] + aapl_columns]
amd_df = combined_df[['date', 'minute'] + amd_columns]
amzn_df = combined_df[['date', 'minute'] + amzn_columns]
fb_df = combined_df[['date', 'minute'] + fb_columns]
msft_df = combined_df[['date', 'minute'] + msft_columns]
nflx_df = combined_df[['date', 'minute'] + nflx_columns]
nvda_df = combined_df[['date', 'minute'] + nvda_columns]
tsla_df = combined_df[['date', 'minute'] + tsla_columns]
v_df = combined_df[['date', 'minute'] + v_columns]
xom_df = combined_df[['date', 'minute'] + xom_columns]

# %%
pip install statsmodels
# Out:
# Requirement already satisfied: statsmodels in c:\users\dan\appdata\local\programs\python\python312\lib\site-packages (0.14.2)
# Requirement already satisfied: numpy>=1.22.3 in c:\users\dan\appdata\local\programs\python\python312\lib\site-packages (from statsmodels) (1.26.4)
# Requirement already satisfied: scipy!=1.9.2,>=1.8 in c:\users\dan\appdata\local\programs\python\python312\lib\site-packages (from statsmodels) (1.13.0)
# Requirement already satisfied: pandas!=2.1.0,>=1.4 in c:\users\dan\appdata\local\programs\python\python312\lib\site-packages (from statsmodels) (2.2.2)
# Requirement already satisfied: patsy>=0.5.6 in c:\users\dan\appdata\local\programs\python\python312\lib\site-packages (from statsmodels) (0.5.6)
# Requirement already satisfied: packaging>=21.3 in c:\users\dan\appdata\local\programs\python\python312\lib\site-packages (from statsmodels) (24.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\dan\appdata\local\programs\python\python312\lib\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\dan\appdata\local\programs\python\python312\lib\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\dan\appdata\local\programs\python\python312\lib\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2024.1)
# Requirement already satisfied: six in c:\users\dan\appdata\local\programs\python\python312\lib\site-packages (from patsy>=0.5.6->statsmodels) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa.arima.model import ARIMA
from sklearn.metrics import mean_squared_error
from statsmodels.tsa.statespace.sarimax import SARIMAX

# %%
amd_df.describe()
# Out:
#                                 date       minute     amd_open     amd_high  \
# count                           9624  9624.000000  9624.000000  9624.000000
# mean   2019-04-09 03:11:58.204488448  1253.725998    27.380011    27.400555
# min              2019-03-25 00:00:00   700.000000    24.570000    24.630000
# 25%              2019-04-01 00:00:00  1089.750000    26.380000    26.400000
# 50%              2019-04-09 00:00:00  1244.000000    27.685000    27.703550
# 75%              2019-04-17 00:00:00  1429.000000    28.134925    28.150000
# max              2019-04-25 00:00:00  1959.000000    29.940000    29.950000
# std                              NaN   206.543178     1.219043     1.219219
#
#            amd_low    amd_close    amd_volume
# count  9624.000000  9624.000000  9.624000e+03
# mean     27.358313    27.379558  1.525650e+05
# min      24.550000    24.570000  1.000000e+00
# 25%      26.370000    26.380000  4.812600e+04
# 50%      27.670000    27.687000  9.046500e+04
# 75%      28.115000    28.134475  1.762560e+05
# max      29.910000    29.940000  6.790500e+06
# std       1.218810     1.219294  2.290598e+05

# %%
aapl_df.describe()
# Out:
#                                 date       minute    aapl_open    aapl_high  \
# count                           9624  9624.000000  9624.000000  9624.000000
# mean   2019-04-09 03:11:58.204488448  1253.725998    48.560365    48.577694
# min              2019-03-25 00:00:00   700.000000    45.426200    45.554000
# 25%              2019-04-01 00:00:00  1089.750000    47.101800    47.133075
# 50%              2019-04-09 00:00:00  1244.000000    48.860550    48.873100
# 75%              2019-04-17 00:00:00  1429.000000    49.735525    49.753225
# max              2019-04-25 00:00:00  1959.000000    51.215700    51.219300
# std                              NaN   206.543178     1.504355     1.501730
#
#           aapl_low   aapl_close   aapl_volume
# count  9624.000000  9624.000000  9.624000e+03
# mean     48.540799    48.560485  2.606200e+05
# min      38.001800    45.428700  4.070300e+00
# 25%      47.069800    47.104025  9.219110e+04
# 50%      48.848250    48.859600  1.517785e+05
# 75%      49.713925    49.735475  2.644032e+05
# max      51.199700    51.214400  3.304670e+07
# std       1.511551     1.504773  9.153498e+05

# %%
import pandas as pd
from statsmodels.tsa.statespace.sarimax import SARIMAX
import matplotlib.pyplot as plt

def run_arima(df, stock_name, order=(5,3,0), seasonal_order=(0,0,0,0), future_periods=10):
    df['minute_str'] = df['minute'].apply(lambda x: f"{int(x):04d}")
    
    # Create a datetime index from the date / minute to a more consumable format by ml
    df['datetime'] = pd.to_datetime(df['date'].astype(str) + ' ' + df['minute_str'], format='%Y-%m-%d %H%M')
    df.set_index('datetime', inplace=True)
    df.sort_index(inplace=True)
    df['date_only'] = df.index.date
    date_counts = df['date_only'].value_counts()
    
    # PLT plot of the whole time series data
    plt.figure(figsize=(10, 5))
    date_counts.plot(kind='bar')
    plt.title('Data Distribution Across Dates')
    plt.xlabel('Date')
    plt.ylabel('Count')
    plt.show()

    #ARIMA modeling
    close_price = df[f'{stock_name}_close']
    model = SARIMAX(close_price, order=order, seasonal_order=seasonal_order, enforce_stationarity=False, enforce_invertibility=False)
    results = model.fit(disp=False)
    
    # Make future predictions
    last_date = df.index[-1]
    future_dates = pd.date_range(start=last_date, periods=future_periods + 1, freq='T')[1:]
    forecast = results.get_forecast(steps=future_periods)
    mean_forecast = forecast.predicted_mean
    conf_int = forecast.conf_int()
    
    # Statistic analysis
    mean_forecast.index = future_dates
    conf_int.index = future_dates
    
    # Plot the Graph
    plt.figure(figsize=(10, 5))
    plt.plot(close_price.tail(100).index, close_price.tail(100), label='Observed')
    plt.plot(mean_forecast.index, mean_forecast, color='r', label='Forecast')
    plt.fill_between(conf_int.index, conf_int.iloc[:, 0], conf_int.iloc[:, 1], color='pink', label='Confidence Interval')
    plt.title(f'Forecasting the next {future_periods} periods for {stock_name}')
    plt.legend()
    plt.show()

    return results.summary()

# Example Usage
if 'combined_df' in locals():
    result_summary = run_arima(combined_df, 'aapl') 
    print(result_summary)
else:
    print("DataFrame not found. Please ensure your DataFrame is loaded and named correctly.")
# Out:
# c:\Users\Dan\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\Dan\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\Dan\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# C:\Users\Dan\AppData\Local\Temp\ipykernel_3144\3619622878.py:27: FutureWarning: 'T' is deprecated and will be removed in a future version, please use 'min' instead.
#   future_dates = pd.date_range(start=last_date, periods=future_periods + 1, freq='T')[1:]
# c:\Users\Dan\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# c:\Users\Dan\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:             aapl_close   No. Observations:                 9624
# Model:               SARIMAX(5, 3, 0)   Log Likelihood               17163.918
# Date:                Wed, 01 May 2024   AIC                         -34315.837
# Time:                        19:59:50   BIC                         -34272.810
# Sample:                             0   HQIC                        -34301.244
#                                - 9624
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -1.5192      0.003   -475.027      0.000      -1.525      -1.513
# ar.L2         -1.5612      0.006   -245.420      0.000      -1.574      -1.549
# ar.L3         -1.2586      0.008   -156.672      0.000      -1.274      -1.243
# ar.L4         -0.7642      0.007   -105.659      0.000      -0.778      -0.750
# ar.L5         -0.2899      0.004    -71.962      0.000      -0.298      -0.282
# sigma2         0.0016   6.59e-06    250.332      0.000       0.002       0.002
# ===================================================================================
# Ljung-Box (L1) (Q):                  52.02   Jarque-Bera (JB):            958059.82
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.55   Skew:                            -0.43
# Prob(H) (two-sided):                  0.00   Kurtosis:                        51.89
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
# Extract necessary columns for each stock
aapl_columns = [col for col in combined_df.columns if 'aapl' in col.lower()]
amd_columns = [col for col in combined_df.columns if 'amd' in col.lower()]
amzn_columns = [col for col in combined_df.columns if 'amzn' in col.lower()]
fb_columns = [col for col in combined_df.columns if 'fb' in col.lower()]
msft_columns = [col for col in combined_df.columns if 'msft' in col.lower()]
nflx_columns = [col for col in combined_df.columns if 'nflx' in col.lower()]
nvda_columns = [col for col in combined_df.columns if 'nvda' in col.lower()]
tsla_columns = [col for col in combined_df.columns if 'tsla' in col.lower()]
v_columns = [col for col in combined_df.columns if 'v' in col.lower()]
xom_columns = [col for col in combined_df.columns if 'xom' in col.lower()]

# Create separate DataFrames for each stock
aapl_df = combined_df[['date', 'minute'] + aapl_columns]
amd_df = combined_df[['date', 'minute'] + amd_columns]
amzn_df = combined_df[['date', 'minute'] + amzn_columns]
fb_df = combined_df[['date', 'minute'] + fb_columns]
msft_df = combined_df[['date', 'minute'] + msft_columns]
nflx_df = combined_df[['date', 'minute'] + nflx_columns]
nvda_df = combined_df[['date', 'minute'] + nvda_columns]
tsla_df = combined_df[['date', 'minute'] + tsla_columns]
v_df = combined_df[['date', 'minute'] + v_columns]
xom_df = combined_df[['date', 'minute'] + xom_columns]

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, LSTM
import matplotlib.pyplot as plt

# Long Short-Term Memory model with hyperparmeter tuning
def run_lstm_and_plot(df, stock_name, lstm_units=50, dense_units=25, batch_size=32, epochs=20, seq_length=10, future_periods=30):
    df['date'] = df['date'].astype(str)
    df['minute'] = df['minute'].apply(lambda x: f"{int(x):04d}")

    # Create a datetime index from the date / minute to a more consumable format by ml
    df.set_index(pd.to_datetime(df['date'] + ' ' + df['minute'], format='%Y-%m-%d %H%M'), inplace=True)
    df.drop(['date', 'minute'], axis=1, inplace=True)

    # Normalize the data
    scaler = MinMaxScaler()
    scaled_data = scaler.fit_transform(df)

    # Function to create sequences
    def create_sequences(data, seq_length):
        xs = []
        ys = []
        for i in range(len(data)-seq_length-1):
            x = data[i:(i+seq_length)]
            y = data[i+seq_length]
            xs.append(x)
            ys.append(y)
        return np.array(xs), np.array(ys)

    # Create sequences
    X, y = create_sequences(scaled_data, seq_length)

    # Split the data
    train_size = int(len(X) * 0.8)
    X_train, X_test = X[:train_size], X[train_size:]
    y_train, y_test = y[:train_size], y[train_size:]

    # Build the LSTM model
    model = Sequential()
    model.add(LSTM(lstm_units, return_sequences=True, input_shape=(X_train.shape[1], X_train.shape[2])))
    model.add(LSTM(lstm_units))
    model.add(Dense(dense_units))
    model.add(Dense(y_train.shape[1]))

    model.compile(optimizer='adam', loss='mean_squared_error')
    model.fit(X_train, y_train, batch_size=batch_size, epochs=epochs, validation_data=(X_test, y_test))

    # Making predictions
    predictions = model.predict(X_test)
    predictions = scaler.inverse_transform(predictions)  # Inverse transform 

    y_test_actual = scaler.inverse_transform(y_test)

    # Predict future periods
    last_sequence = scaled_data[-seq_length:]
    current_sequence = last_sequence.reshape((1, seq_length, X_train.shape[2]))
    future_predictions = []

    for _ in range(future_periods):
        next_prediction = model.predict(current_sequence)[0]
        future_predictions.append(next_prediction)
        # Reshape next_prediction to match the 3D shape expected by LSTM
        next_prediction_reshaped = next_prediction.reshape((1, 1, X_train.shape[2]))
        current_sequence = np.append(current_sequence[:, 1:, :], next_prediction_reshaped, axis=1)

    future_predictions = scaler.inverse_transform(future_predictions)


    # Plotting the results
    plt.figure(figsize=(12, 6))
    total_sequence = np.concatenate((y_test_actual[:, 0], future_predictions[:, 0]))
    plt.plot(np.arange(len(y_test_actual)), y_test_actual[:, 0], label='Actual Close Price')
    plt.plot(np.arange(len(y_test_actual), len(y_test_actual) + future_periods), future_predictions[:, 0], label='Future Predictions', color='red')
    plt.title(f'{stock_name} Stock Price Prediction and Future Forecast')
    plt.xlabel('Time')
    plt.ylabel('Stock Price')
    plt.legend()
    plt.show()

    return model

# Example usage
model_aapl = run_lstm_and_plot(aapl_df, 'AAPL', lstm_units=64, dense_units=32, batch_size=16, epochs=5, seq_length=20, future_periods=30)
model_amd = run_lstm_and_plot(amd_df, 'AMD', lstm_units=32, dense_units=16, batch_size=16, epochs=5, seq_length=15, future_periods=30)
# Out:
# C:\Users\Dan\AppData\Local\Temp\ipykernel_3144\2926613849.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['date'] = df['date'].astype(str)
# C:\Users\Dan\AppData\Local\Temp\ipykernel_3144\2926613849.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['minute'] = df['minute'].apply(lambda x: f"{int(x):04d}")
# C:\Users\Dan\AppData\Local\Temp\ipykernel_3144\2926613849.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(['date', 'minute'], axis=1, inplace=True)
# c:\Users\Dan\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/5
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 15s 20ms/step - loss: 0.0129 - val_loss: 5.3787e-04
# Epoch 2/5
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 9s 20ms/step - loss: 3.3928e-04 - val_loss: 3.1602e-04
# Epoch 3/5
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 9s 18ms/step - loss: 2.4057e-04 - val_loss: 4.6697e-04
# Epoch 4/5
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - loss: 2.0874e-04 - val_loss: 8.6375e-04
# Epoch 5/5
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 10s 21ms/step - loss: 2.4844e-04 - val_loss: 0.0011
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Epoch 1/5
# C:\Users\Dan\AppData\Local\Temp\ipykernel_3144\2926613849.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['date'] = df['date'].astype(str)
# C:\Users\Dan\AppData\Local\Temp\ipykernel_3144\2926613849.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['minute'] = df['minute'].apply(lambda x: f"{int(x):04d}")
# C:\Users\Dan\AppData\Local\Temp\ipykernel_3144\2926613849.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(['date', 'minute'], axis=1, inplace=True)
# c:\Users\Dan\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 12s 13ms/step - loss: 0.0223 - val_loss: 3.8273e-04
# Epoch 2/5
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - loss: 4.5565e-04 - val_loss: 3.6556e-04
# Epoch 3/5
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 7s 15ms/step - loss: 4.0604e-04 - val_loss: 4.6115e-04
# Epoch 4/5
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 3.9070e-04 - val_loss: 3.6645e-04
# Epoch 5/5
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - loss: 3.3098e-04 - val_loss: 2.9179e-04
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step

# %% [markdown]
# Notice that we need the series to be stationary so we do more processing

# %%
# Extract necessary columns for each stock
aapl_columns = [col for col in combined_df.columns if 'aapl' in col.lower()]
amd_columns = [col for col in combined_df.columns if 'amd' in col.lower()]
amzn_columns = [col for col in combined_df.columns if 'amzn' in col.lower()]
fb_columns = [col for col in combined_df.columns if 'fb' in col.lower()]
msft_columns = [col for col in combined_df.columns if 'msft' in col.lower()]
nflx_columns = [col for col in combined_df.columns if 'nflx' in col.lower()]
nvda_columns = [col for col in combined_df.columns if 'nvda' in col.lower()]
tsla_columns = [col for col in combined_df.columns if 'tsla' in col.lower()]
v_columns = [col for col in combined_df.columns if 'v' in col.lower()]
xom_columns = [col for col in combined_df.columns if 'xom' in col.lower()]

# Create separate DataFrames for each stock
aapl_df = combined_df[['date', 'minute'] + aapl_columns]
amd_df = combined_df[['date', 'minute'] + amd_columns]
amzn_df = combined_df[['date', 'minute'] + amzn_columns]
fb_df = combined_df[['date', 'minute'] + fb_columns]
msft_df = combined_df[['date', 'minute'] + msft_columns]
nflx_df = combined_df[['date', 'minute'] + nflx_columns]
nvda_df = combined_df[['date', 'minute'] + nvda_columns]
tsla_df = combined_df[['date', 'minute'] + tsla_columns]
v_df = combined_df[['date', 'minute'] + v_columns]
xom_df = combined_df[['date', 'minute'] + xom_columns]

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt
import pandas as pd

# %%
aapl_columns
# Out:
# ['aapl_open', 'aapl_high', 'aapl_low', 'aapl_close', 'aapl_volume']

# %%
def reset_columns():
    # Extract necessary columns for each stock
    aapl_columns = [col for col in combined_df.columns if 'aapl' in col.lower()]
    amd_columns = [col for col in combined_df.columns if 'amd' in col.lower()]
    amzn_columns = [col for col in combined_df.columns if 'amzn' in col.lower()]
    fb_columns = [col for col in combined_df.columns if 'fb' in col.lower()]
    msft_columns = [col for col in combined_df.columns if 'msft' in col.lower()]
    nflx_columns = [col for col in combined_df.columns if 'nflx' in col.lower()]
    nvda_columns = [col for col in combined_df.columns if 'nvda' in col.lower()]
    tsla_columns = [col for col in combined_df.columns if 'tsla' in col.lower()]
    v_columns = [col for col in combined_df.columns if 'v' in col.lower()]
    xom_columns = [col for col in combined_df.columns if 'xom' in col.lower()]

    # Create separate DataFrames for each stock
    aapl_df = combined_df[['date', 'minute'] + aapl_columns]
    amd_df = combined_df[['date', 'minute'] + amd_columns]
    amzn_df = combined_df[['date', 'minute'] + amzn_columns]
    fb_df = combined_df[['date', 'minute'] + fb_columns]
    msft_df = combined_df[['date', 'minute'] + msft_columns]
    nflx_df = combined_df[['date', 'minute'] + nflx_columns]
    nvda_df = combined_df[['date', 'minute'] + nvda_columns]
    tsla_df = combined_df[['date', 'minute'] + tsla_columns]
    v_df = combined_df[['date', 'minute'] + v_columns]
    xom_df = combined_df[['date', 'minute'] + xom_columns]
def run_random_forest(df, stock_name, n_estimators=100, max_depth=None, random_state=42, future_periods=30):
    # Ensure date and minute are properly formatted as strings
    df['datetime'] = pd.to_datetime(df['date'].astype(str) + ' ' + df['minute'].astype(str).str.zfill(4), format='%Y-%m-%d %H%M')
    df.set_index('datetime', inplace=True)
    df.drop(['date', 'minute'], axis=1, inplace=True)

    # Split the data into features and target
    X = df.drop(f'{stock_name}_close', axis=1)
    y = df[f'{stock_name}_close']
    
    # Split the dataset into training and testing sets
    split_point = int(len(X) * 0.8)
    X_train, X_test = X[:split_point], X[split_point:]
    y_train, y_test = y[:split_point], y[split_point:]

    # Initialize and train the Random Forest model
    model = RandomForestRegressor(n_estimators=n_estimators, max_depth=max_depth, random_state=random_state)
    model.fit(X_train, y_train)

    # Predictions
    predictions = model.predict(X_test)
    mse = mean_squared_error(y_test, predictions)
    
    # Future prediction setup
    future_X = pd.DataFrame(np.tile(X_test.iloc[-1], (future_periods, 1)), columns=X_test.columns)
    future_predictions = model.predict(future_X)

    # Plotting the results
    plt.figure(figsize=(12, 6))
    total_sequence = np.concatenate((y_test.to_numpy(), future_predictions))
    plt.plot(np.arange(len(y_test)), y_test, label='Actual Close Price')
    plt.plot(np.arange(len(y_test), len(y_test) + future_periods), future_predictions, label='Future Predictions', color='green')
    plt.title(f'{stock_name} Stock Price Prediction and Future Forecast using Random Forest')
    plt.xlabel('Time')
    plt.ylabel('Close Price')
    plt.legend()
    plt.show()

    print(f'MSE for {stock_name}: {mse}')
    return model
# Run Random Forest
rf_model = run_random_forest(amd_df, 'AMD'.lower(), n_estimators=100, max_depth=10, future_periods=30)
reset_columns()
# Out:
# C:\Users\Dan\AppData\Local\Temp\ipykernel_3144\1127240954.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['datetime'] = pd.to_datetime(df['date'].astype(str) + ' ' + df['minute'].astype(str).str.zfill(4), format='%Y-%m-%d %H%M')
# C:\Users\Dan\AppData\Local\Temp\ipykernel_3144\1127240954.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(['date', 'minute'], axis=1, inplace=True)
# MSE for amd: 0.0003054710607503063

# %%
def reset(stock_name, df):
    df_col = [col for col in combined_df.columns if f'{stock_name}' in col.lower()]
    df = df[['date', 'minute'] + df_col]
    return df


# Stocks to process
stocks = {
    'aapl': aapl_df,
    'amd': amd_df,
    'amzn': amzn_df,
    'fb': fb_df,
    'msft': msft_df,
    'nflx': nflx_df,
    'nvda': nvda_df,
    'tsla': tsla_df,
    'v': v_df,
    'xom': xom_df
}

# Process each stock
for stock_name, df in stocks.items():
    print(f"Processing {stock_name} stock data...")
    reset_columns()
    # Run ARIMA
    print(f"Running ARIMA for {stock_name}...")
    arima_summary = run_arima(combined_df, f"{stock_name}")
    print(arima_summary)
    


print(f"Finished processing {stock_name}.")
print("\n" + "="*50 + "\n")
# Out:
# Processing aapl stock data...
# Running ARIMA for aapl...
# c:\Users\Dan\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\Dan\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\Dan\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# C:\Users\Dan\AppData\Local\Temp\ipykernel_3144\3619622878.py:27: FutureWarning: 'T' is deprecated and will be removed in a future version, please use 'min' instead.
#   future_dates = pd.date_range(start=last_date, periods=future_periods + 1, freq='T')[1:]
# c:\Users\Dan\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# c:\Users\Dan\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:             aapl_close   No. Observations:                 9624
# Model:               SARIMAX(5, 3, 0)   Log Likelihood               17163.918
# Date:                Wed, 01 May 2024   AIC                         -34315.837
# Time:                        20:01:47   BIC                         -34272.810
# Sample:                             0   HQIC                        -34301.244
#                                - 9624
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -1.5192      0.003   -475.027      0.000      -1.525      -1.513
# ar.L2         -1.5612      0.006   -245.420      0.000      -1.574      -1.549
# ar.L3         -1.2586      0.008   -156.672      0.000      -1.274      -1.243
# ar.L4         -0.7642      0.007   -105.659      0.000      -0.778      -0.750
# ar.L5         -0.2899      0.004    -71.962      0.000      -0.298      -0.282
# sigma2         0.0016   6.59e-06    250.332      0.000       0.002       0.002
# ===================================================================================
# Ljung-Box (L1) (Q):                  52.02   Jarque-Bera (JB):            958059.82
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.55   Skew:                            -0.43
# Prob(H) (two-sided):                  0.00   Kurtosis:                        51.89
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# Processing amd stock data...
# Running ARIMA for amd...
# c:\Users\Dan\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\Dan\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\Dan\AppData\Local\Temp\ipykernel_3144\3619622878.py:27: FutureWarning: 'T' is deprecated and will be removed in a future version, please use 'min' instead.
#   future_dates = pd.date_range(start=last_date, periods=future_periods + 1, freq='T')[1:]
# c:\Users\Dan\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# c:\Users\Dan\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:              amd_close   No. Observations:                 9624
# Model:               SARIMAX(5, 3, 0)   Log Likelihood               15507.657
# Date:                Wed, 01 May 2024   AIC                         -31003.313
# Time:                        20:01:50   BIC                         -30960.286
# Sample:                             0   HQIC                        -30988.721
#                                - 9624
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -1.4238      0.003   -468.617      0.000      -1.430      -1.418
# ar.L2         -1.4379      0.005   -269.282      0.000      -1.448      -1.427
# ar.L3         -1.1573      0.006   -178.185      0.000      -1.170      -1.145
# ar.L4         -0.7127      0.006   -111.134      0.000      -0.725      -0.700
# ar.L5         -0.2911      0.004    -70.758      0.000      -0.299      -0.283
# sigma2         0.0023   8.65e-06    268.992      0.000       0.002       0.002
# ===================================================================================
# Ljung-Box (L1) (Q):                  44.80   Jarque-Bera (JB):            388750.09
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.54   Skew:                             0.55
# Prob(H) (two-sided):                  0.00   Kurtosis:                        34.13
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# Processing amzn stock data...
# Running ARIMA for amzn...
# c:\Users\Dan\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\Dan\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\Dan\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# C:\Users\Dan\AppData\Local\Temp\ipykernel_3144\3619622878.py:27: FutureWarning: 'T' is deprecated and will be removed in a future version, please use 'min' instead.
#   future_dates = pd.date_range(start=last_date, periods=future_periods + 1, freq='T')[1:]
# c:\Users\Dan\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# c:\Users\Dan\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:             amzn_close   No. Observations:                 9624
# Model:               SARIMAX(5, 3, 0)   Log Likelihood              -19047.200
# Date:                Wed, 01 May 2024   AIC                          38106.400
# Time:                        20:01:53   BIC                          38149.427
# Sample:                             0   HQIC                         38120.992
#                                - 9624
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -1.7113      0.001  -1485.918      0.000      -1.714      -1.709
# ar.L2         -1.7495      0.003   -612.496      0.000      -1.755      -1.744
# ar.L3         -1.4407      0.005   -289.605      0.000      -1.450      -1.431
# ar.L4         -0.9158      0.005   -191.849      0.000      -0.925      -0.906
# ar.L5         -0.3225      0.002   -141.443      0.000      -0.327      -0.318
# sigma2         3.0762      0.005    633.589      0.000       3.067       3.086
# ===================================================================================
# Ljung-Box (L1) (Q):                  47.68   Jarque-Bera (JB):          65964916.24
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               2.09   Skew:                            -4.68
# Prob(H) (two-sided):                  0.00   Kurtosis:                       408.65
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# Processing fb stock data...
# Running ARIMA for fb...
# c:\Users\Dan\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\Dan\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\Dan\AppData\Local\Temp\ipykernel_3144\3619622878.py:27: FutureWarning: 'T' is deprecated and will be removed in a future version, please use 'min' instead.
#   future_dates = pd.date_range(start=last_date, periods=future_periods + 1, freq='T')[1:]
# c:\Users\Dan\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# c:\Users\Dan\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:               fb_close   No. Observations:                 9624
# Model:               SARIMAX(5, 3, 0)   Log Likelihood                 936.586
# Date:                Wed, 01 May 2024   AIC                          -1861.172
# Time:                        20:01:56   BIC                          -1818.145
# Sample:                             0   HQIC                         -1846.579
#                                - 9624
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -1.5026      0.002   -716.193      0.000      -1.507      -1.499
# ar.L2         -1.5566      0.003   -476.802      0.000      -1.563      -1.550
# ar.L3         -1.2338      0.003   -363.408      0.000      -1.240      -1.227
# ar.L4         -0.7597      0.003   -250.368      0.000      -0.766      -0.754
# ar.L5         -0.3144      0.002   -129.182      0.000      -0.319      -0.310
# sigma2         0.0482   7.77e-05    620.429      0.000       0.048       0.048
# ===================================================================================
# Ljung-Box (L1) (Q):                  68.09   Jarque-Bera (JB):         144093619.26
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               3.31   Skew:                            10.45
# Prob(H) (two-sided):                  0.00   Kurtosis:                       602.33
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# Processing msft stock data...
# Running ARIMA for msft...
# c:\Users\Dan\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\Dan\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\Dan\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# C:\Users\Dan\AppData\Local\Temp\ipykernel_3144\3619622878.py:27: FutureWarning: 'T' is deprecated and will be removed in a future version, please use 'min' instead.
#   future_dates = pd.date_range(start=last_date, periods=future_periods + 1, freq='T')[1:]
# c:\Users\Dan\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# c:\Users\Dan\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:             msft_close   No. Observations:                 9624
# Model:               SARIMAX(5, 3, 0)   Log Likelihood                9564.767
# Date:                Wed, 01 May 2024   AIC                         -19117.534
# Time:                        20:01:59   BIC                         -19074.507
# Sample:                             0   HQIC                        -19102.941
#                                - 9624
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -1.4912      0.003   -579.614      0.000      -1.496      -1.486
# ar.L2         -1.4842      0.005   -303.161      0.000      -1.494      -1.475
# ar.L3         -1.2020      0.006   -196.527      0.000      -1.214      -1.190
# ar.L4         -0.7677      0.006   -128.990      0.000      -0.779      -0.756
# ar.L5         -0.2976      0.004    -80.242      0.000      -0.305      -0.290
# sigma2         0.0080   2.11e-05    378.706      0.000       0.008       0.008
# ===================================================================================
# Ljung-Box (L1) (Q):                  46.91   Jarque-Bera (JB):           1493494.72
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.45   Skew:                             0.90
# Prob(H) (two-sided):                  0.00   Kurtosis:                        64.03
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# Processing nflx stock data...
# Running ARIMA for nflx...
# c:\Users\Dan\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\Dan\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\Dan\AppData\Local\Temp\ipykernel_3144\3619622878.py:27: FutureWarning: 'T' is deprecated and will be removed in a future version, please use 'min' instead.
#   future_dates = pd.date_range(start=last_date, periods=future_periods + 1, freq='T')[1:]
# c:\Users\Dan\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# c:\Users\Dan\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:             nflx_close   No. Observations:                 9624
# Model:               SARIMAX(5, 3, 0)   Log Likelihood               -7394.709
# Date:                Wed, 01 May 2024   AIC                          14801.419
# Time:                        20:02:01   BIC                          14844.446
# Sample:                             0   HQIC                         14816.012
#                                - 9624
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -1.3325      0.002   -826.030      0.000      -1.336      -1.329
# ar.L2         -1.3035      0.002   -590.996      0.000      -1.308      -1.299
# ar.L3         -1.0369      0.003   -344.941      0.000      -1.043      -1.031
# ar.L4         -0.6211      0.003   -218.693      0.000      -0.627      -0.616
# ar.L5         -0.2491      0.002   -110.687      0.000      -0.253      -0.245
# sigma2         0.2726      0.001    388.889      0.000       0.271       0.274
# ===================================================================================
# Ljung-Box (L1) (Q):                  34.89   Jarque-Bera (JB):           3513295.71
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               2.37   Skew:                            -0.20
# Prob(H) (two-sided):                  0.00   Kurtosis:                        96.64
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# Processing nvda stock data...
# Running ARIMA for nvda...
# c:\Users\Dan\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\Dan\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\Dan\AppData\Local\Temp\ipykernel_3144\3619622878.py:27: FutureWarning: 'T' is deprecated and will be removed in a future version, please use 'min' instead.
#   future_dates = pd.date_range(start=last_date, periods=future_periods + 1, freq='T')[1:]
# c:\Users\Dan\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# c:\Users\Dan\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:             nvda_close   No. Observations:                 9624
# Model:               SARIMAX(5, 3, 0)   Log Likelihood               -1110.676
# Date:                Wed, 01 May 2024   AIC                           2233.353
# Time:                        20:02:04   BIC                           2276.380
# Sample:                             0   HQIC                          2247.945
#                                - 9624
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -1.5165      0.002   -743.097      0.000      -1.521      -1.513
# ar.L2         -1.5279      0.004   -355.095      0.000      -1.536      -1.519
# ar.L3         -1.2412      0.006   -212.603      0.000      -1.253      -1.230
# ar.L4         -0.7930      0.006   -137.995      0.000      -0.804      -0.782
# ar.L5         -0.3275      0.004    -80.548      0.000      -0.336      -0.320
# sigma2         0.0738      0.000    385.968      0.000       0.073       0.074
# ===================================================================================
# Ljung-Box (L1) (Q):                  70.78   Jarque-Bera (JB):          11187420.84
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.82   Skew:                             2.56
# Prob(H) (two-sided):                  0.00   Kurtosis:                       170.02
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# Processing tsla stock data...
# Running ARIMA for tsla...
# c:\Users\Dan\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\Dan\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\Dan\AppData\Local\Temp\ipykernel_3144\3619622878.py:27: FutureWarning: 'T' is deprecated and will be removed in a future version, please use 'min' instead.
#   future_dates = pd.date_range(start=last_date, periods=future_periods + 1, freq='T')[1:]
# c:\Users\Dan\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# c:\Users\Dan\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:             tsla_close   No. Observations:                 9624
# Model:               SARIMAX(5, 3, 0)   Log Likelihood                6946.576
# Date:                Wed, 01 May 2024   AIC                         -13881.151
# Time:                        20:02:05   BIC                         -13838.124
# Sample:                             0   HQIC                        -13866.559
#                                - 9624
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -1.4995      0.001  -2127.657      0.000      -1.501      -1.498
# ar.L2         -1.4919      0.002   -965.003      0.000      -1.495      -1.489
# ar.L3         -1.1735      0.002   -479.507      0.000      -1.178      -1.169
# ar.L4         -0.7071      0.003   -213.266      0.000      -0.714      -0.701
# ar.L5         -0.2739      0.002   -178.442      0.000      -0.277      -0.271
# sigma2         0.0138   1.08e-05   1279.964      0.000       0.014       0.014
# ===================================================================================
# Ljung-Box (L1) (Q):                  44.35   Jarque-Bera (JB):         210056261.52
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.29   Skew:                           -10.01
# Prob(H) (two-sided):                  0.00   Kurtosis:                       726.79
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# Processing v stock data...
# Running ARIMA for v...
# c:\Users\Dan\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\Dan\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\Dan\AppData\Local\Temp\ipykernel_3144\3619622878.py:27: FutureWarning: 'T' is deprecated and will be removed in a future version, please use 'min' instead.
#   future_dates = pd.date_range(start=last_date, periods=future_periods + 1, freq='T')[1:]
# c:\Users\Dan\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# c:\Users\Dan\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                v_close   No. Observations:                 9624
# Model:               SARIMAX(5, 3, 0)   Log Likelihood                6305.798
# Date:                Wed, 01 May 2024   AIC                         -12599.597
# Time:                        20:02:07   BIC                         -12556.570
# Sample:                             0   HQIC                        -12585.004
#                                - 9624
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -1.6446      0.003   -620.804      0.000      -1.650      -1.639
# ar.L2         -1.7102      0.005   -356.671      0.000      -1.720      -1.701
# ar.L3         -1.4022      0.006   -237.009      0.000      -1.414      -1.391
# ar.L4         -0.8316      0.006   -143.753      0.000      -0.843      -0.820
# ar.L5         -0.3084      0.004    -87.363      0.000      -0.315      -0.302
# sigma2         0.0158   5.06e-05    311.799      0.000       0.016       0.016
# ===================================================================================
# Ljung-Box (L1) (Q):                  68.45   Jarque-Bera (JB):            746823.96
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.09   Skew:                            -0.00
# Prob(H) (two-sided):                  0.02   Kurtosis:                        46.17
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# Processing xom stock data...
# Running ARIMA for xom...
# c:\Users\Dan\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\Dan\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\Dan\AppData\Local\Temp\ipykernel_3144\3619622878.py:27: FutureWarning: 'T' is deprecated and will be removed in a future version, please use 'min' instead.
#   future_dates = pd.date_range(start=last_date, periods=future_periods + 1, freq='T')[1:]
# c:\Users\Dan\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# c:\Users\Dan\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:              xom_close   No. Observations:                 9624
# Model:               SARIMAX(5, 3, 0)   Log Likelihood               13309.461
# Date:                Wed, 01 May 2024   AIC                         -26606.922
# Time:                        20:02:10   BIC                         -26563.895
# Sample:                             0   HQIC                        -26592.329
#                                - 9624
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -1.6549      0.003   -543.214      0.000      -1.661      -1.649
# ar.L2         -1.7138      0.006   -286.709      0.000      -1.725      -1.702
# ar.L3         -1.3706      0.008   -179.615      0.000      -1.386      -1.356
# ar.L4         -0.8308      0.007   -119.036      0.000      -0.845      -0.817
# ar.L5         -0.3001      0.004    -74.260      0.000      -0.308      -0.292
# sigma2         0.0037   1.44e-05    255.297      0.000       0.004       0.004
# ===================================================================================
# Ljung-Box (L1) (Q):                  63.34   Jarque-Bera (JB):            539211.74
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.11   Skew:                             0.38
# Prob(H) (two-sided):                  0.00   Kurtosis:                        39.68
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# Finished processing xom.
#
# ==================================================

# %%
aapl_columns = [col for col in combined_df.columns if 'aapl' in col.lower()]
amd_columns = [col for col in combined_df.columns if 'amd' in col.lower()]
amzn_columns = [col for col in combined_df.columns if 'amzn' in col.lower()]
fb_columns = [col for col in combined_df.columns if 'fb' in col.lower()]
msft_columns = [col for col in combined_df.columns if 'msft' in col.lower()]
nflx_columns = [col for col in combined_df.columns if 'nflx' in col.lower()]
nvda_columns = [col for col in combined_df.columns if 'nvda' in col.lower()]
tsla_columns = [col for col in combined_df.columns if 'tsla' in col.lower()]
xom_columns = [col for col in combined_df.columns if 'xom' in col.lower()]

# Create separate DataFrames for each stock
aapl_df = combined_df[['date', 'minute'] + aapl_columns]
amd_df = combined_df[['date', 'minute'] + amd_columns]
amzn_df = combined_df[['date', 'minute'] + amzn_columns]
fb_df = combined_df[['date', 'minute'] + fb_columns]
msft_df = combined_df[['date', 'minute'] + msft_columns]
nflx_df = combined_df[['date', 'minute'] + nflx_columns]
nvda_df = combined_df[['date', 'minute'] + nvda_columns]
tsla_df = combined_df[['date', 'minute'] + tsla_columns]
xom_df = combined_df[['date', 'minute'] + xom_columns]
# Run LSTM
model_aapl = run_lstm_and_plot(aapl_df, 'AAPL', lstm_units=64, dense_units=32, batch_size=16, epochs=5, seq_length=20, future_periods=30)
reset_columns()
model_amd = run_lstm_and_plot(amd_df, 'AMD', lstm_units=32, dense_units=16, batch_size=16, epochs=5, seq_length=15, future_periods=30)
reset_columns()
model_amzn = run_lstm_and_plot(amzn_df, 'AMZN', lstm_units=64, dense_units=32, batch_size=16, epochs=5, seq_length=20, future_periods=30)
reset_columns()
model_fb = run_lstm_and_plot(fb_df, 'FB', lstm_units=32, dense_units=16, batch_size=16, epochs=5, seq_length=15, future_periods=30)
reset_columns()
model_msft = run_lstm_and_plot(msft_df, 'MSFT', lstm_units=64, dense_units=32, batch_size=16, epochs=5, seq_length=20, future_periods=30)
reset_columns()
model_nflx = run_lstm_and_plot(nflx_df, 'NFLX', lstm_units=32, dense_units=16, batch_size=16, epochs=5, seq_length=15, future_periods=30)
reset_columns()
model_nvda = run_lstm_and_plot(nvda_df, 'NVDA', lstm_units=64, dense_units=32, batch_size=16, epochs=5, seq_length=20, future_periods=30)
reset_columns()
model_tsla = run_lstm_and_plot(tsla_df, 'TSLA', lstm_units=32, dense_units=16, batch_size=16, epochs=5, seq_length=15, future_periods=30)
reset_columns()
model_xom = run_lstm_and_plot(xom_df, 'XOM', lstm_units=32, dense_units=16, batch_size=16, epochs=5, seq_length=15, future_periods=30)
# Out:
# C:\Users\Dan\AppData\Local\Temp\ipykernel_3144\2926613849.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['date'] = df['date'].astype(str)
# C:\Users\Dan\AppData\Local\Temp\ipykernel_3144\2926613849.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['minute'] = df['minute'].apply(lambda x: f"{int(x):04d}")
# C:\Users\Dan\AppData\Local\Temp\ipykernel_3144\2926613849.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(['date', 'minute'], axis=1, inplace=True)
# c:\Users\Dan\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/5
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 15s 21ms/step - loss: 0.0114 - val_loss: 5.7241e-04
# Epoch 2/5
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 10s 21ms/step - loss: 2.6920e-04 - val_loss: 4.9784e-04
# Epoch 3/5
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - loss: 2.0719e-04 - val_loss: 3.9365e-04
# Epoch 4/5
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 9s 18ms/step - loss: 3.0075e-04 - val_loss: 3.7325e-04
# Epoch 5/5
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 9s 18ms/step - loss: 2.5610e-04 - val_loss: 4.3939e-04
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# C:\Users\Dan\AppData\Local\Temp\ipykernel_3144\2926613849.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['date'] = df['date'].astype(str)
# C:\Users\Dan\AppData\Local\Temp\ipykernel_3144\2926613849.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['minute'] = df['minute'].apply(lambda x: f"{int(x):04d}")
# C:\Users\Dan\AppData\Local\Temp\ipykernel_3144\2926613849.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(['date', 'minute'], axis=1, inplace=True)
# c:\Users\Dan\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/5
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 12s 13ms/step - loss: 0.0303 - val_loss: 3.9385e-04
# Epoch 2/5
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 7s 14ms/step - loss: 4.5854e-04 - val_loss: 4.5066e-04
# Epoch 3/5
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 10s 12ms/step - loss: 3.9207e-04 - val_loss: 4.7639e-04
# Epoch 4/5
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - loss: 4.1643e-04 - val_loss: 3.0412e-04
# Epoch 5/5
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - loss: 3.4515e-04 - val_loss: 4.1056e-04
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# C:\Users\Dan\AppData\Local\Temp\ipykernel_3144\2926613849.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['date'] = df['date'].astype(str)
# C:\Users\Dan\AppData\Local\Temp\ipykernel_3144\2926613849.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['minute'] = df['minute'].apply(lambda x: f"{int(x):04d}")
# C:\Users\Dan\AppData\Local\Temp\ipykernel_3144\2926613849.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(['date', 'minute'], axis=1, inplace=True)
# c:\Users\Dan\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/5
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 15s 18ms/step - loss: 0.0046 - val_loss: 0.0015
# Epoch 2/5
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - loss: 1.8750e-04 - val_loss: 5.8792e-04
# Epoch 3/5
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 9s 18ms/step - loss: 1.5818e-04 - val_loss: 5.6034e-04
# Epoch 4/5
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - loss: 1.3996e-04 - val_loss: 4.2137e-04
# Epoch 5/5
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 9s 18ms/step - loss: 1.2022e-04 - val_loss: 0.0013
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# C:\Users\Dan\AppData\Local\Temp\ipykernel_3144\2926613849.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['date'] = df['date'].astype(str)
# C:\Users\Dan\AppData\Local\Temp\ipykernel_3144\2926613849.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['minute'] = df['minute'].apply(lambda x: f"{int(x):04d}")
# C:\Users\Dan\AppData\Local\Temp\ipykernel_3144\2926613849.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(['date', 'minute'], axis=1, inplace=True)
# c:\Users\Dan\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/5
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 17s 17ms/step - loss: 0.0101 - val_loss: 0.0037
# Epoch 2/5
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - loss: 8.7797e-05 - val_loss: 0.0038
# Epoch 3/5
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - loss: 7.0446e-05 - val_loss: 0.0040
# Epoch 4/5
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 1.6137e-04 - val_loss: 0.0034
# Epoch 5/5
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - loss: 1.1268e-04 - val_loss: 0.0022
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# C:\Users\Dan\AppData\Local\Temp\ipykernel_3144\2926613849.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['date'] = df['date'].astype(str)
# C:\Users\Dan\AppData\Local\Temp\ipykernel_3144\2926613849.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['minute'] = df['minute'].apply(lambda x: f"{int(x):04d}")
# C:\Users\Dan\AppData\Local\Temp\ipykernel_3144\2926613849.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(['date', 'minute'], axis=1, inplace=True)
# c:\Users\Dan\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/5
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 16s 19ms/step - loss: 0.0012 - val_loss: 0.0017
# Epoch 2/5
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 9s 18ms/step - loss: 1.2199e-04 - val_loss: 0.0011
# Epoch 3/5
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 8s 17ms/step - loss: 1.1715e-04 - val_loss: 5.6531e-04
# Epoch 4/5
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 10s 21ms/step - loss: 1.1997e-04 - val_loss: 0.0017
# Epoch 5/5
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 7s 15ms/step - loss: 1.2125e-04 - val_loss: 3.7956e-04
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# C:\Users\Dan\AppData\Local\Temp\ipykernel_3144\2926613849.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['date'] = df['date'].astype(str)
# C:\Users\Dan\AppData\Local\Temp\ipykernel_3144\2926613849.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['minute'] = df['minute'].apply(lambda x: f"{int(x):04d}")
# C:\Users\Dan\AppData\Local\Temp\ipykernel_3144\2926613849.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(['date', 'minute'], axis=1, inplace=True)
# c:\Users\Dan\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/5
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 12s 12ms/step - loss: 0.0132 - val_loss: 7.2171e-04
# Epoch 2/5
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - loss: 3.8653e-04 - val_loss: 5.7297e-04
# Epoch 3/5
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - loss: 3.1814e-04 - val_loss: 3.8577e-04
# Epoch 4/5
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - loss: 2.9469e-04 - val_loss: 9.8085e-04
# Epoch 5/5
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - loss: 3.0578e-04 - val_loss: 3.0562e-04
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# C:\Users\Dan\AppData\Local\Temp\ipykernel_3144\2926613849.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['date'] = df['date'].astype(str)
# C:\Users\Dan\AppData\Local\Temp\ipykernel_3144\2926613849.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['minute'] = df['minute'].apply(lambda x: f"{int(x):04d}")
# C:\Users\Dan\AppData\Local\Temp\ipykernel_3144\2926613849.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(['date', 'minute'], axis=1, inplace=True)
# c:\Users\Dan\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/5
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 16s 21ms/step - loss: 0.0191 - val_loss: 5.7896e-04
# Epoch 2/5
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 10s 21ms/step - loss: 5.5126e-04 - val_loss: 5.7424e-04
# Epoch 3/5
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - loss: 6.0947e-04 - val_loss: 6.3338e-04
# Epoch 4/5
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 10s 22ms/step - loss: 5.5110e-04 - val_loss: 0.0011
# Epoch 5/5
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 10s 21ms/step - loss: 5.7680e-04 - val_loss: 4.8665e-04
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# C:\Users\Dan\AppData\Local\Temp\ipykernel_3144\2926613849.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['date'] = df['date'].astype(str)
# C:\Users\Dan\AppData\Local\Temp\ipykernel_3144\2926613849.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['minute'] = df['minute'].apply(lambda x: f"{int(x):04d}")
# C:\Users\Dan\AppData\Local\Temp\ipykernel_3144\2926613849.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(['date', 'minute'], axis=1, inplace=True)
# c:\Users\Dan\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/5
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 12s 14ms/step - loss: 0.0180 - val_loss: 8.1210e-04
# Epoch 2/5
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - loss: 4.5900e-04 - val_loss: 8.0817e-04
# Epoch 3/5
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - loss: 4.2141e-04 - val_loss: 6.7671e-04
# Epoch 4/5
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - loss: 4.1284e-04 - val_loss: 6.0878e-04
# Epoch 5/5
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 10s 11ms/step - loss: 5.0309e-04 - val_loss: 4.8786e-04
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# C:\Users\Dan\AppData\Local\Temp\ipykernel_3144\2926613849.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['date'] = df['date'].astype(str)
# C:\Users\Dan\AppData\Local\Temp\ipykernel_3144\2926613849.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['minute'] = df['minute'].apply(lambda x: f"{int(x):04d}")
# C:\Users\Dan\AppData\Local\Temp\ipykernel_3144\2926613849.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(['date', 'minute'], axis=1, inplace=True)
# c:\Users\Dan\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/5
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 11s 12ms/step - loss: 0.0204 - val_loss: 5.6587e-04
# Epoch 2/5
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 10s 12ms/step - loss: 5.2336e-04 - val_loss: 4.7688e-04
# Epoch 3/5
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 10s 11ms/step - loss: 5.1765e-04 - val_loss: 4.1171e-04
# Epoch 4/5
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - loss: 3.4734e-04 - val_loss: 3.7463e-04
# Epoch 5/5
# 481/481 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - loss: 3.6193e-04 - val_loss: 4.0760e-04
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step

# %%
aapl_columns = [col for col in combined_df.columns if 'aapl' in col.lower()]
amd_columns = [col for col in combined_df.columns if 'amd' in col.lower()]
amzn_columns = [col for col in combined_df.columns if 'amzn' in col.lower()]
fb_columns = [col for col in combined_df.columns if 'fb' in col.lower()]
msft_columns = [col for col in combined_df.columns if 'msft' in col.lower()]
nflx_columns = [col for col in combined_df.columns if 'nflx' in col.lower()]
nvda_columns = [col for col in combined_df.columns if 'nvda' in col.lower()]
tsla_columns = [col for col in combined_df.columns if 'tsla' in col.lower()]
v_columns = [col for col in combined_df.columns if 'v' in col.lower()]
xom_columns = [col for col in combined_df.columns if 'xom' in col.lower()]

# Create separate DataFrames for each stock
aapl_df = combined_df[['date', 'minute'] + aapl_columns]
amd_df = combined_df[['date', 'minute'] + amd_columns]
amzn_df = combined_df[['date', 'minute'] + amzn_columns]
fb_df = combined_df[['date', 'minute'] + fb_columns]
msft_df = combined_df[['date', 'minute'] + msft_columns]
nflx_df = combined_df[['date', 'minute'] + nflx_columns]
nvda_df = combined_df[['date', 'minute'] + nvda_columns]
tsla_df = combined_df[['date', 'minute'] + tsla_columns]
v_df = combined_df[['date', 'minute'] + v_columns]
xom_df = combined_df[['date', 'minute'] + xom_columns]
reset_columns()
# Run Random Forest
rf_model = run_random_forest(amd_df, 'AMD'.lower(), n_estimators=100, max_depth=10, future_periods=30)
reset_columns()
# Out:
# C:\Users\Dan\AppData\Local\Temp\ipykernel_3144\1608630735.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['datetime'] = pd.to_datetime(df['date'].astype(str) + ' ' + df['minute'].astype(str).str.zfill(4), format='%Y-%m-%d %H%M')
# C:\Users\Dan\AppData\Local\Temp\ipykernel_3144\1608630735.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(['date', 'minute'], axis=1, inplace=True)
# MSE for amd: 0.0003054710607503063

# %%
pip install jupytext
# Out:
# Collecting jupytext
#   Downloading jupytext-1.16.1-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: markdown-it-py>=1.0 in c:\users\dan\appdata\local\programs\python\python312\lib\site-packages (from jupytext) (3.0.0)
# Collecting mdit-py-plugins (from jupytext)
#   Downloading mdit_py_plugins-0.4.0-py3-none-any.whl.metadata (2.7 kB)
# Collecting nbformat (from jupytext)
#   Downloading nbformat-5.10.4-py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: packaging in c:\users\dan\appdata\local\programs\python\python312\lib\site-packages (from jupytext) (24.0)
# Collecting pyyaml (from jupytext)
#   Downloading PyYAML-6.0.1-cp312-cp312-win_amd64.whl.metadata (2.1 kB)
# Collecting toml (from jupytext)
#   Downloading toml-0.10.2-py2.py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: mdurl~=0.1 in c:\users\dan\appdata\local\programs\python\python312\lib\site-packages (from markdown-it-py>=1.0->jupytext) (0.1.2)
# Collecting fastjsonschema>=2.15 (from nbformat->jupytext)
#   Downloading fastjsonschema-2.19.1-py3-none-any.whl.metadata (2.1 kB)
# Collecting jsonschema>=2.6 (from nbformat->jupytext)
#   Downloading jsonschema-4.22.0-py3-none-any.whl.metadata (8.2 kB)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\dan\appdata\roaming\python\python312\site-packages (from nbformat->jupytext) (5.7.2)
# Requirement already satisfied: traitlets>=5.1 in c:\users\dan\appdata\roaming\python\python312\site-packages (from nbformat->jupytext) (5.14.3)
# Collecting attrs>=22.2.0 (from jsonschema>=2.6->nbformat->jupytext)
#   Downloading attrs-23.2.0-py3-none-any.whl.metadata (9.5 kB)
# Collecting jsonschema-specifications>=2023.03.6 (from jsonschema>=2.6->nbformat->jupytext)
#   Downloading jsonschema_specifications-2023.12.1-py3-none-any.whl.metadata (3.0 kB)
# Collecting referencing>=0.28.4 (from jsonschema>=2.6->nbformat->jupytext)
#   Downloading referencing-0.35.1-py3-none-any.whl.metadata (2.8 kB)
# Collecting rpds-py>=0.7.1 (from jsonschema>=2.6->nbformat->jupytext)
#   Downloading rpds_py-0.18.0-cp312-none-win_amd64.whl.metadata (4.2 kB)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\dan\appdata\roaming\python\python312\site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat->jupytext) (4.2.1)
# Requirement already satisfied: pywin32>=300 in c:\users\dan\appdata\roaming\python\python312\site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat->jupytext) (306)
# Downloading jupytext-1.16.1-py3-none-any.whl (152 kB)
#    ---------------------------------------- 0.0/152.7 kB ? eta -:--:--
#    ---------------------------------------- 152.7/152.7 kB 4.6 MB/s eta 0:00:00
# Downloading mdit_py_plugins-0.4.0-py3-none-any.whl (54 kB)
#    ---------------------------------------- 0.0/54.1 kB ? eta -:--:--
#    ---------------------------------------- 54.1/54.1 kB ? eta 0:00:00
# Downloading nbformat-5.10.4-py3-none-any.whl (78 kB)
#    ---------------------------------------- 0.0/78.5 kB ? eta -:--:--
#    ---------------------------------------- 78.5/78.5 kB 4.3 MB/s eta 0:00:00
# Downloading PyYAML-6.0.1-cp312-cp312-win_amd64.whl (138 kB)
#    ---------------------------------------- 0.0/138.7 kB ? eta -:--:--
#    ---------------------------------------- 138.7/138.7 kB 8.0 MB/s eta 0:00:00
# Downloading toml-0.10.2-py2.py3-none-any.whl (16 kB)
# Downloading fastjsonschema-2.19.1-py3-none-any.whl (23 kB)
# Downloading jsonschema-4.22.0-py3-none-any.whl (88 kB)
#    ---------------------------------------- 0.0/88.3 kB ? eta -:--:--
#    ---------------------------------------- 88.3/88.3 kB 4.9 MB/s eta 0:00:00
# Downloading attrs-23.2.0-py3-none-any.whl (60 kB)
#    ---------------------------------------- 0.0/60.8 kB ? eta -:--:--
#    ---------------------------------------- 60.8/60.8 kB 3.2 MB/s eta 0:00:00
# Downloading jsonschema_specifications-2023.12.1-py3-none-any.whl (18 kB)
# Downloading referencing-0.35.1-py3-none-any.whl (26 kB)
# Downloading rpds_py-0.18.0-cp312-none-win_amd64.whl (206 kB)
#    ---------------------------------------- 0.0/206.3 kB ? eta -:--:--
#    ---------------------------------------- 206.3/206.3 kB 6.1 MB/s eta 0:00:00
# Installing collected packages: fastjsonschema, toml, rpds-py, pyyaml, attrs, referencing, mdit-py-plugins, jsonschema-specifications, jsonschema, nbformat, jupytext
# Successfully installed attrs-23.2.0 fastjsonschema-2.19.1 jsonschema-4.22.0 jsonschema-specifications-2023.12.1 jupytext-1.16.1 mdit-py-plugins-0.4.0 nbformat-5.10.4 pyyaml-6.0.1 referencing-0.35.1 rpds-py-0.18.0 toml-0.10.2
# Note: you may need to restart the kernel to use updated packages.
